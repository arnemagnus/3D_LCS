# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#from pymod_velfield import flowmap_interpolated

# %%
import pymod_velfield as pvf

# %%
print(pvf.__doc__)
# Out:
# This module 'pymod_velfield' is auto-generated with f2py (version:2).
# Functions:
# Fortran 90/95 modules:
#   flowmap_interpolated --- flowmap_endpoints().

# %%
print(pvf.flowmap_interpolated.__doc__)
# Out:
# x_end = flowmap_endpoints(amp,eps,omg,x,x_samp,ts,tf,h,t_samp,kx,ky,kt,[nx,ny,nx_s,ny_s,nt_s])
#
# Wrapper for ``flowmap_endpoints``.
#
# Parameters
# ----------
# amp : input float
# eps : input float
# omg : input float
# x : input rank-3 array('f') with bounds (nx,ny,2)
# x_samp : input rank-3 array('f') with bounds (nx_s,ny_s,2)
# ts : input float
# tf : input float
# h : input float
# t_samp : input rank-1 array('f') with bounds (nt_s)
# kx : input int
# ky : input int
# kt : input int
#
# Other Parameters
# ----------------
# nx : input int, optional
#     Default: shape(x,0)
# ny : input int, optional
#     Default: shape(x,1)
# nx_s : input int, optional
#     Default: shape(x_samp,0)
# ny_s : input int, optional
#     Default: shape(x_samp,1)
# nt_s : input int, optional
#     Default: len(t_samp)
#
# Returns
# -------
# x_end : rank-3 array('f') with bounds (nx,ny,2)

# %%
A = 0.1
eps = 0.1
w = 2*np.pi/10

x = np.linspace(0,1,10)
y = np.linspace(0,2,10)

pos = np.array(np.meshgrid(x,y,indexing='ij')).transpose(1,2,0)

t = 0.24

# %%
dg.vel(t,pos,A,eps,w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5645a0f3856e> in <module>()
# ----> 1 dg.vel(t,pos,A,eps,w)
#
# NameError: name 'dg' is not defined

# %%
print(dg.__doc__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4132f453e089> in <module>()
# ----> 1 print(dg.__doc__)
#
# NameError: name 'dg' is not defined

# %%
np.pi
# Out:
# 3.141592653589793

# %%
print(flowmap_interpolated.__doc__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-35f45153366e> in <module>()
# ----> 1 print(flowmap_interpolated.__doc__)
#
# NameError: name 'flowmap_interpolated' is not defined

# %%
A = 0.1
eps = 0.1
w = 2*np.pi/10

# %%
nx = 200
ny = 100

nx_s = 200
ny_s = 100
t0_s = 0.
tf_s = 1000.
nt_s = 100

# %%
xmin, xmax = 0,2
ymin,ymax = 0,1

x = np.linspace(xmin,xmax,nx)
y = np.linspace(ymin,ymax,ny)
t_s = np.linspace(t0_s,tf_s,nt_s)

x_s = np.linspace(xmin,xmax,nx_s)
y_s = np.linspace(ymin,ymax,ny_s)

t0 = 0.
tf = 20.
h = 0.01

g0 = np.array(np.meshgrid(x,y,indexing='ij')).transpose(1,2,0)
gs = np.array(np.meshgrid(x_s,y_s,indexing='ij')).transpose(1,2,0)

# %%
amp,eps,omg,x,x_samp,ts,tf,h,t_samp,kx,ky,kt,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-59379a1ce6a5> in <module>()
# ----> 1 amp,eps,omg,x,x_samp,ts,tf,h,t_samp,kx,ky,kt,
#
# NameError: name 'amp' is not defined

# %%
pos_fin = pvf.flowmap_interpolated.flowmap_endpoints(amp=A,eps=eps,omg=w,x=np.asfortranarray(g0),x_samp=np.asfortranarray(gs),ts=t0,tf=tf,h=h,t_samp=t_s,kx=3,ky=3,kt=3)

# %%
A = 0.1
eps = 0.1
w = 2*np.pi/10
t = 0.24
x = np.linspace(0,2,100)
y = np.linspace(0,1,50)
pos = np.array(np.meshgrid(x,y,indexing='ij')).transpose(1,2,0)

# %%
v = velocityfield.vel(t,pos,A,eps,w)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.quiver(pos[:,:,0],pos[:,:,1],v[:,:,0],v[:,:,1])

# %%
pos[:,0,0]
# Out:
# array([ 0.        ,  0.02020202,  0.04040404,  0.06060606,  0.08080808,
#         0.1010101 ,  0.12121212,  0.14141414,  0.16161616,  0.18181818,
#         0.2020202 ,  0.22222222,  0.24242424,  0.26262626,  0.28282828,
#         0.3030303 ,  0.32323232,  0.34343434,  0.36363636,  0.38383838,
#         0.4040404 ,  0.42424242,  0.44444444,  0.46464646,  0.48484848,
#         0.50505051,  0.52525253,  0.54545455,  0.56565657,  0.58585859,
#         0.60606061,  0.62626263,  0.64646465,  0.66666667,  0.68686869,
#         0.70707071,  0.72727273,  0.74747475,  0.76767677,  0.78787879,
#         0.80808081,  0.82828283,  0.84848485,  0.86868687,  0.88888889,
#         0.90909091,  0.92929293,  0.94949495,  0.96969697,  0.98989899,
#         1.01010101,  1.03030303,  1.05050505,  1.07070707,  1.09090909,
#         1.11111111,  1.13131313,  1.15151515,  1.17171717,  1.19191919,
#         1.21212121,  1.23232323,  1.25252525,  1.27272727,  1.29292929,
# ...
